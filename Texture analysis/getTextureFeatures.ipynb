# %%
# !python --version
# Out:
# Python 3.9.16

# %%
#Define functions to extract features from images and test a method
#Always run this first cell for all the imports and global variable definitions
#To be run in the workenvAutoencoder2 environment

from skimage.feature import graycomatrix, graycoprops
import numpy as np
from tqdm import tqdm
import os

import pywt
from skimage.io import imread
from skimage.color import rgb2gray

from skimage.feature import local_binary_pattern
from skimage.util import img_as_ubyte
from skimage.transform import radon
from scipy.ndimage import gaussian_filter
from scipy.ndimage import generic_filter
from scipy.stats import kurtosis, skew
import nibabel as nib
import SimpleITK as sitk
import mahotas as mh
import tifffile as tif
import xgboost as xgb

from radiomics import featureextractor

MAIN_DIR = 'E:/AAV para enfermedades renales/LSFM combined images/TextureAnalysis/Tiles3D/CenteredInGlom-prepared'


def normalize_image(image):
    # Normalize the image to the range [0, 1]
    image = image - np.min(image)
    image = image / np.max(image)
    return image


#Define several functions to extract features from an image
#-----------------------------------------------------------------------------------------

#General Features
def calculate_statistical_features(image):
    mean_val = np.mean(image)
    variance_val = np.var(image)
    skewness_val = skew(image,axis=None)
    kurtosis_val = kurtosis(image,axis=None)
    #hist, _ = np.histogram(image, bins=256, range=(0, 255))
    #hist = hist / np.sum(hist)
    #entropy_val = -np.sum(hist * np.log2(hist + np.finfo(float).eps))
    return mean_val, variance_val, skewness_val, kurtosis_val
    
#Wavelet features in 3D
def calculate_wavelet_features3D(image):
    # Perform 3D discrete wavelet transform
    coeffs = pywt.dwtn(image, 'db1')
    
    # Extract approximation and detail coefficients
    cA = coeffs['aaa']
    cH = coeffs['daa']
    cV = coeffs['ada']
    cD = coeffs['aad']
    
    # Compute the mean of the coefficients
    approx_coeff_mean = np.mean(cA)
    horiz_coeff_mean = np.mean(cH)
    vert_coeff_mean = np.mean(cV)
    depth_coeff_mean = np.mean(cD)

    return approx_coeff_mean, horiz_coeff_mean, vert_coeff_mean, depth_coeff_mean

    
#Fourier features in 3D
def calculate_fourier_features_3d(image):
    # Perform 3D Fast Fourier Transform
    fft_image = np.fft.fftn(image)
    fft_magnitude = np.abs(fft_image)

    # Find the dominant frequency
    dominant_frequency_magnitude = np.max(fft_magnitude)
    
    # Calculate the total energy
    total_energy = np.sum(fft_magnitude ** 2)

    return dominant_frequency_magnitude, total_energy
    
#Local Binary Patterns (LBP) uniformity in 3D
def lbp_code_3d(neighborhood):
    center = neighborhood[len(neighborhood) // 2]
    binary_pattern = (neighborhood >= center).astype(int)
    binary_pattern = np.delete(binary_pattern, len(binary_pattern) // 2)  # Remove the center pixel
    lbp_value = np.dot(binary_pattern, 1 << np.arange(binary_pattern.size)[::-1])
    return lbp_value

def calculate_lbp_uniformity_3d(image, radius=1):
    # Define the neighborhood shape for 3D LBP
    neighborhood_shape = (2 * radius + 1, 2 * radius + 1, 2 * radius + 1)
    
    # Apply the 3D LBP calculation
    lbp_image = generic_filter(image, lbp_code_3d, size=neighborhood_shape, mode='constant', cval=0)
    
    # Compute the histogram of LBP values
    lbp_hist, _ = np.histogram(lbp_image.ravel(), bins=np.arange(0, 2**(neighborhood_shape[0]**3 - 1) + 1), range=(0, 2**(neighborhood_shape[0]**3 - 1)))
    lbp_hist = lbp_hist / np.sum(lbp_hist)  # Normalize histogram
    
    # Calculate uniformity measure
    lbp_uniformity = np.sum(lbp_hist**2)

    return lbp_uniformity


def calculate_porosity(image):
    threshold = np.mean(image)  # Use mean intensity as a threshold
    hole_area = np.sum(image < threshold)  # Count low-intensity pixels (holes)
    total_area = image.size  # Total number of pixels
    porosity = hole_area / total_area
    return porosity
#-----------------------------------------------------------------------------------------

#Define a function to extract all features from a set of images and produce a numpy array
def extract_features(MAIN_DIR,setName):
    # Define GLCM parameters
    featureNames = 'mean_val', 'variance_val', 'skewness_val', 'kurtosis_val',\
    'approx_coeff_mean', 'horiz_coeff_mean', 'vert_coeff_mean', 'depth_coeff_mean',\
    'dominant_frequency_magnitude', 'total_energy',\
    'lbp_uniformity',\
    'porosity'
    
    initDir = os.getcwd()

    os.chdir(MAIN_DIR)

    #Entry 0 to store the Healthy features, entry 1 to store the Pathological features
    data = [[], []]

    print(f'Processing images from the {setName} set:')

    for stateName in os.listdir(f'{setName}'):
        #For the Healthy and Pathological folders
        if stateName == 'Healthy':
            stateNum = 0
            
        elif stateName == 'Pathological':
            stateNum = 1
            
        print(f'{stateName} images')

        for imName in tqdm(os.listdir(f'{setName}/{stateName}')):
                
            # Load and normalize the image
            image = tif.imread(f'{setName}/{stateName}/{imName}')
            image = normalize_image(image)

            # Statistical features
            mean_val, variance_val, skewness_val, kurtosis_val = calculate_statistical_features(image)         
            
            # Wavelet features
            approx_coeff_mean, horiz_coeff_mean, vert_coeff_mean, depth_coeff_mean = calculate_wavelet_features3D(image)

            # Fourier features
            dominant_frequency_magnitude, total_energy = calculate_fourier_features_3d(image)

            # Average diameter of circles with radon transform
            #average_diameter_radon,average_radial_intensity_radon = measure_average_diameter_radon(image)

            #LBP uniformity
            lbp_uniformity = calculate_lbp_uniformity_3d(image)

            #Porosity
            porosity = calculate_porosity(image)

            features = np.array([mean_val, variance_val, skewness_val, kurtosis_val,  
                                 approx_coeff_mean, horiz_coeff_mean, vert_coeff_mean, depth_coeff_mean,
                                 dominant_frequency_magnitude, total_energy, 
                                 lbp_uniformity,
                                 porosity])
            
            #Save the features in the corresponding list
            data[stateNum].append(features)

    healthyFeatures = np.vstack(data[0])
    pathologicalFeatures = np.vstack(data[1])

    healthyLabels = np.zeros(healthyFeatures.shape[0],dtype=int)
    pathologicalLabels = np.ones(pathologicalFeatures.shape[0],dtype=int)

    allFeatures = np.vstack([healthyFeatures, pathologicalFeatures])
    allLabels = np.hstack([healthyLabels, pathologicalLabels])

    os.chdir(initDir)
    return allFeatures, allLabels, featureNames

def get_test_results(method,testData,testLabels,dataTuple = False):
    #Test a method and print the results

    if dataTuple is True:
        #The dataformat is a tuple with the features and the labels
        testData = xgb.DMatrix(testData, label=testLabels)

    #Positives will be the Pathological images
    truePos = 0
    trueNeg = 0
    falsePos = 0
    falseNeg = 0

    predictions = method.predict(testData)

    #If the predictions are not a binary vector
    if not np.all(np.isin(predictions, [0, 1])):
        #Threshold them to make them binary
        predictions = np.where(predictions >= 0.5, 1, 0)

    print('predictions')
    print(predictions)

    print('ground truth labels')
    print(testLabels)
    
    for i in range(len(predictions)):
        if predictions[i] == testLabels[i] and testLabels[i] == 1:
            truePos += 1
        elif predictions[i] == testLabels[i] and testLabels[i] == 0:
            trueNeg += 1
        elif predictions[i] != testLabels[i] and testLabels[i] == 0:
            falsePos += 1
        elif predictions[i] != testLabels[i] and testLabels[i] == 1:
            falseNeg += 1
        #print(f'Predicted: {predictions[i]}, True: {test_labels[i]}')

    print(f'Total predictions: {len(predictions)}')
    print(f'True positives: {truePos}')
    print(f'True negatives: {trueNeg}')
    print(f'False positives: {falsePos}')
    print(f'False negatives: {falseNeg}')
    print(f'Accuracy: {(truePos+trueNeg)/len(predictions)}')
    print(f'Sensitivity: {truePos/(truePos+falseNeg)}')
    print(f'Specificity: {trueNeg/(trueNeg+falsePos)}')
    print(f'f1-score: {2*truePos/(2*truePos+falsePos+falseNeg)}')

# %%
testData,testLabels,featureNames = extract_features(MAIN_DIR,'test')
header = ','.join(featureNames)
np.savetxt('testData.txt', testData, delimiter=',', header=header, comments='')
np.savetxt('testLabels.txt', testLabels, delimiter=',', header='Label', comments='')

valData,valLabels,featureNames = extract_features(MAIN_DIR,'validation')
header = ','.join(featureNames)
np.savetxt('valData.txt', valData, delimiter=',', header=header, comments='')
np.savetxt('valLabels.txt', valLabels, delimiter=',', header='Label', comments='', fmt='%d')

trainData,trainLabels,featureNames = extract_features(MAIN_DIR,'train')
header = ','.join(featureNames)
np.savetxt('trainData.txt', trainData, delimiter=',', header=header, comments='')
np.savetxt('trainLabels.txt', trainLabels, delimiter=',', header='Label', comments='', fmt='%d')
# Out:
# Processing images from the test set:
# Healthy images
#   0%|          | 0/40 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▎         | 1/40 [01:48<1:10:13, 108.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 2/40 [03:33<1:07:34, 106.70s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 3/40 [05:17<1:05:02, 105.48s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|█         | 4/40 [07:00<1:02:34, 104.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▎        | 5/40 [08:41<1:00:07, 103.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▌        | 6/40 [10:23<58:14, 102.78s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  18%|█▊        | 7/40 [12:05<56:26, 102.63s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  20%|██        | 8/40 [13:47<54:35, 102.37s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▎       | 9/40 [15:29<52:49, 102.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  25%|██▌       | 10/40 [17:11<51:02, 102.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  28%|██▊       | 11/40 [18:53<49:21, 102.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  30%|███       | 12/40 [20:35<47:38, 102.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  32%|███▎      | 13/40 [22:16<45:51, 101.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  35%|███▌      | 14/40 [23:57<43:58, 101.50s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  38%|███▊      | 15/40 [25:36<41:57, 100.71s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  40%|████      | 16/40 [27:14<40:00, 100.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  42%|████▎     | 17/40 [28:53<38:11, 99.63s/it] GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  45%|████▌     | 18/40 [30:32<36:24, 99.30s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  48%|████▊     | 19/40 [32:10<34:38, 98.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  50%|█████     | 20/40 [33:49<32:58, 98.90s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  52%|█████▎    | 21/40 [35:27<31:17, 98.82s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  55%|█████▌    | 22/40 [37:06<29:38, 98.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  57%|█████▊    | 23/40 [38:44<27:57, 98.70s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  60%|██████    | 24/40 [40:23<26:17, 98.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  62%|██████▎   | 25/40 [42:01<24:39, 98.61s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  65%|██████▌   | 26/40 [43:40<22:59, 98.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  68%|██████▊   | 27/40 [45:18<21:21, 98.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  70%|███████   | 28/40 [46:57<19:42, 98.51s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  72%|███████▎  | 29/40 [48:36<18:04, 98.59s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  75%|███████▌  | 30/40 [50:14<16:25, 98.59s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  78%|███████▊  | 31/40 [51:53<14:47, 98.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  80%|████████  | 32/40 [53:31<13:08, 98.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  82%|████████▎ | 33/40 [55:09<11:28, 98.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  85%|████████▌ | 34/40 [56:48<09:50, 98.44s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  88%|████████▊ | 35/40 [58:27<08:13, 98.66s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 36/40 [1:00:06<06:34, 98.68s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▎| 37/40 [1:01:44<04:55, 98.61s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 38/40 [1:03:23<03:17, 98.64s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 39/40 [1:05:01<01:38, 98.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 40/40 [1:06:40<00:00, 100.02s/it]
# Pathological images
#   0%|          | 0/40 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▎         | 1/40 [01:38<1:04:13, 98.81s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 2/40 [03:17<1:02:33, 98.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 3/40 [04:55<1:00:43, 98.48s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|█         | 4/40 [06:34<59:14, 98.74s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▎        | 5/40 [08:13<57:35, 98.73s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▌        | 6/40 [09:51<55:52, 98.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  18%|█▊        | 7/40 [11:30<54:15, 98.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  20%|██        | 8/40 [13:09<52:34, 98.58s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▎       | 9/40 [14:48<51:01, 98.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  25%|██▌       | 10/40 [16:27<49:22, 98.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  28%|██▊       | 11/40 [18:05<47:42, 98.72s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  30%|███       | 12/40 [19:43<45:59, 98.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  32%|███▎      | 13/40 [21:22<44:19, 98.52s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  35%|███▌      | 14/40 [23:01<42:44, 98.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  38%|███▊      | 15/40 [24:39<41:02, 98.51s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  40%|████      | 16/40 [26:17<39:24, 98.52s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  42%|████▎     | 17/40 [27:56<37:46, 98.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  45%|████▌     | 18/40 [29:35<36:08, 98.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  48%|████▊     | 19/40 [31:13<34:30, 98.60s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  50%|█████     | 20/40 [32:52<32:52, 98.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  52%|█████▎    | 21/40 [34:30<31:11, 98.51s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  55%|█████▌    | 22/40 [36:09<29:34, 98.58s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  57%|█████▊    | 23/40 [37:48<27:55, 98.58s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  60%|██████    | 24/40 [39:26<26:16, 98.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  62%|██████▎   | 25/40 [41:05<24:37, 98.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  65%|██████▌   | 26/40 [42:43<22:58, 98.49s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  68%|██████▊   | 27/40 [44:22<21:21, 98.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  70%|███████   | 28/40 [46:00<19:43, 98.64s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  72%|███████▎  | 29/40 [47:39<18:05, 98.66s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  75%|███████▌  | 30/40 [49:18<16:27, 98.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  78%|███████▊  | 31/40 [50:57<14:48, 98.73s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  80%|████████  | 32/40 [52:35<13:09, 98.65s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  82%|████████▎ | 33/40 [54:14<11:30, 98.71s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  85%|████████▌ | 34/40 [55:53<09:52, 98.72s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  88%|████████▊ | 35/40 [57:31<08:13, 98.64s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 36/40 [59:11<06:35, 98.88s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▎| 37/40 [1:00:51<04:57, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 38/40 [1:02:30<03:18, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 39/40 [1:04:10<01:39, 99.49s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 40/40 [1:05:50<00:00, 98.75s/it]
# Processing images from the validation set:
# Healthy images
#   0%|          | 0/40 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▎         | 1/40 [01:39<1:04:53, 99.83s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 2/40 [03:19<1:03:11, 99.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 3/40 [04:59<1:01:26, 99.63s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|█         | 4/40 [06:38<59:37, 99.38s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▎        | 5/40 [08:16<57:51, 99.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▌        | 6/40 [09:55<56:10, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  18%|█▊        | 7/40 [11:35<54:31, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  20%|██        | 8/40 [13:14<52:54, 99.20s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▎       | 9/40 [14:53<51:13, 99.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  25%|██▌       | 10/40 [16:32<49:32, 99.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  28%|██▊       | 11/40 [18:11<47:52, 99.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  30%|███       | 12/40 [19:50<46:12, 99.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  32%|███▎      | 13/40 [21:29<44:33, 99.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  35%|███▌      | 14/40 [23:08<42:55, 99.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  38%|███▊      | 15/40 [24:47<41:15, 99.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  40%|████      | 16/40 [26:26<39:35, 99.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  42%|████▎     | 17/40 [28:05<37:55, 98.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  45%|████▌     | 18/40 [29:44<36:17, 98.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  48%|████▊     | 19/40 [31:23<34:40, 99.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  50%|█████     | 20/40 [33:02<32:59, 98.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  52%|█████▎    | 21/40 [34:41<31:23, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  55%|█████▌    | 22/40 [36:20<29:40, 98.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  57%|█████▊    | 23/40 [37:59<28:02, 98.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  60%|██████    | 24/40 [39:38<26:23, 98.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  62%|██████▎   | 25/40 [41:16<24:43, 98.87s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  65%|██████▌   | 26/40 [42:55<23:05, 98.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  68%|██████▊   | 27/40 [44:35<21:27, 99.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  70%|███████   | 28/40 [46:14<19:48, 99.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  72%|███████▎  | 29/40 [47:53<18:09, 99.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  75%|███████▌  | 30/40 [49:32<16:32, 99.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  78%|███████▊  | 31/40 [51:12<14:52, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  80%|████████  | 32/40 [52:51<13:13, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  82%|████████▎ | 33/40 [54:30<11:34, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  85%|████████▌ | 34/40 [56:09<09:54, 99.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  88%|████████▊ | 35/40 [57:48<08:15, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 36/40 [59:28<06:37, 99.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▎| 37/40 [1:01:07<04:57, 99.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 38/40 [1:02:46<03:18, 99.26s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 39/40 [1:04:25<01:39, 99.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 40/40 [1:06:05<00:00, 99.13s/it]
# Pathological images
#   0%|          | 0/40 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▎         | 1/40 [01:38<1:04:18, 98.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 2/40 [03:18<1:02:49, 99.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 3/40 [04:57<1:01:13, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|█         | 4/40 [06:37<59:36, 99.35s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▎        | 5/40 [08:16<57:58, 99.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▌        | 6/40 [09:55<56:15, 99.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  18%|█▊        | 7/40 [11:34<54:31, 99.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  20%|██        | 8/40 [13:13<52:48, 99.01s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▎       | 9/40 [14:51<51:05, 98.90s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  25%|██▌       | 10/40 [16:30<49:27, 98.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  28%|██▊       | 11/40 [18:11<48:00, 99.32s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  30%|███       | 12/40 [19:51<46:27, 99.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  32%|███▎      | 13/40 [21:31<44:51, 99.68s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  35%|███▌      | 14/40 [23:10<43:10, 99.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  38%|███▊      | 15/40 [24:49<41:24, 99.36s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  40%|████      | 16/40 [26:28<39:40, 99.20s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  42%|████▎     | 17/40 [28:07<38:00, 99.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  45%|████▌     | 18/40 [29:46<36:22, 99.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  48%|████▊     | 19/40 [31:25<34:44, 99.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  50%|█████     | 20/40 [33:04<33:03, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  52%|█████▎    | 21/40 [34:43<31:19, 98.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  55%|█████▌    | 22/40 [36:22<29:41, 98.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  57%|█████▊    | 23/40 [38:01<28:02, 99.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  60%|██████    | 24/40 [39:40<26:23, 98.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  62%|██████▎   | 25/40 [41:19<24:45, 99.01s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  65%|██████▌   | 26/40 [42:58<23:05, 98.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  68%|██████▊   | 27/40 [44:37<21:28, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  70%|███████   | 28/40 [46:16<19:48, 99.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  72%|███████▎  | 29/40 [47:55<18:10, 99.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  75%|███████▌  | 30/40 [49:35<16:31, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  78%|███████▊  | 31/40 [51:14<14:52, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  80%|████████  | 32/40 [52:53<13:12, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  82%|████████▎ | 33/40 [54:32<11:33, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  85%|████████▌ | 34/40 [56:11<09:54, 99.01s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  88%|████████▊ | 35/40 [57:49<08:14, 98.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 36/40 [59:28<06:35, 98.81s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▎| 37/40 [1:01:06<04:56, 98.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 38/40 [1:02:45<03:17, 98.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 39/40 [1:04:24<01:38, 98.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 40/40 [1:06:03<00:00, 99.09s/it]
# Processing images from the train set:
# Healthy images
#   0%|          | 0/237 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 1/237 [01:39<6:29:56, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 2/237 [03:16<6:24:40, 98.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|▏         | 3/237 [04:55<6:24:11, 98.51s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 4/237 [06:34<6:23:11, 98.68s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 5/237 [08:13<6:21:59, 98.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 6/237 [09:52<6:20:18, 98.78s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 7/237 [11:31<6:18:44, 98.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 8/237 [13:10<6:17:32, 98.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 9/237 [14:49<6:15:46, 98.89s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 10/237 [16:27<6:14:03, 98.87s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 11/237 [18:06<6:12:11, 98.81s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 12/237 [19:45<6:10:45, 98.87s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▌         | 13/237 [21:24<6:09:19, 98.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   6%|▌         | 14/237 [23:03<6:08:06, 99.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   6%|▋         | 15/237 [24:38<6:01:38, 97.74s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   7%|▋         | 16/237 [26:16<6:00:20, 97.83s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   7%|▋         | 17/237 [27:54<5:59:10, 97.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 18/237 [29:32<5:57:15, 97.88s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 19/237 [31:11<5:56:23, 98.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   8%|▊         | 20/237 [32:49<5:55:15, 98.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   9%|▉         | 21/237 [34:28<5:54:00, 98.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   9%|▉         | 22/237 [36:06<5:52:11, 98.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|▉         | 23/237 [37:44<5:50:38, 98.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  10%|█         | 24/237 [39:23<5:49:33, 98.47s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  11%|█         | 25/237 [41:02<5:48:16, 98.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  11%|█         | 26/237 [42:41<5:47:11, 98.73s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  11%|█▏        | 27/237 [44:20<5:45:44, 98.78s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▏        | 28/237 [45:59<5:44:19, 98.85s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  12%|█▏        | 29/237 [47:38<5:42:47, 98.88s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  13%|█▎        | 30/237 [49:17<5:41:11, 98.90s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  13%|█▎        | 31/237 [50:56<5:39:43, 98.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  14%|█▎        | 32/237 [52:35<5:37:57, 98.91s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  14%|█▍        | 33/237 [54:14<5:36:33, 98.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  14%|█▍        | 34/237 [55:53<5:34:47, 98.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▍        | 35/237 [57:32<5:33:08, 98.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  15%|█▌        | 36/237 [59:11<5:31:35, 98.98s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  16%|█▌        | 37/237 [1:00:50<5:29:55, 98.98s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  16%|█▌        | 38/237 [1:02:29<5:28:23, 99.01s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  16%|█▋        | 39/237 [1:04:08<5:26:51, 99.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  17%|█▋        | 40/237 [1:05:47<5:25:14, 99.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  17%|█▋        | 41/237 [1:07:26<5:22:54, 98.85s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
#  16%|█▋        | 13/80 [21:29<1:50:47, 99.22s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  18%|█▊        | 14/80 [23:08<1:49:04, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  19%|█▉        | 15/80 [24:48<1:47:37, 99.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  20%|██        | 16/80 [26:27<1:45:53, 99.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  21%|██▏       | 17/80 [28:07<1:44:24, 99.43s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▎       | 18/80 [29:46<1:42:41, 99.38s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  24%|██▍       | 19/80 [31:25<1:40:46, 99.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  25%|██▌       | 20/80 [33:04<1:39:09, 99.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  26%|██▋       | 21/80 [34:43<1:37:29, 99.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  28%|██▊       | 22/80 [36:22<1:35:51, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  29%|██▉       | 23/80 [38:02<1:34:10, 99.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  30%|███       | 24/80 [39:40<1:32:25, 99.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  31%|███▏      | 25/80 [41:20<1:30:54, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  32%|███▎      | 26/80 [42:59<1:29:18, 99.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  34%|███▍      | 27/80 [44:39<1:27:41, 99.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  35%|███▌      | 28/80 [46:18<1:25:58, 99.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  36%|███▋      | 29/80 [47:57<1:24:20, 99.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  38%|███▊      | 30/80 [49:36<1:22:41, 99.22s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  39%|███▉      | 31/80 [51:15<1:20:59, 99.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  40%|████      | 32/80 [52:54<1:19:19, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  41%|████▏     | 33/80 [54:33<1:17:37, 99.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  42%|████▎     | 34/80 [56:12<1:15:58, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  44%|████▍     | 35/80 [57:52<1:14:28, 99.30s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  45%|████▌     | 36/80 [59:31<1:12:48, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  46%|████▋     | 37/80 [1:01:11<1:11:10, 99.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  48%|████▊     | 38/80 [1:02:50<1:09:29, 99.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  49%|████▉     | 39/80 [1:04:29<1:07:51, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  50%|█████     | 40/80 [1:06:09<1:06:11, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  51%|█████▏    | 41/80 [1:07:47<1:04:24, 99.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  52%|█████▎    | 42/80 [1:09:26<1:02:45, 99.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  54%|█████▍    | 43/80 [1:11:05<1:01:05, 99.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  55%|█████▌    | 44/80 [1:12:44<59:24, 99.01s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  56%|█████▋    | 45/80 [1:14:24<57:56, 99.33s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  57%|█████▊    | 46/80 [1:16:03<56:13, 99.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  59%|█████▉    | 47/80 [1:17:42<54:33, 99.20s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  60%|██████    | 48/80 [1:19:21<52:52, 99.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  61%|██████▏   | 49/80 [1:21:01<51:15, 99.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  62%|██████▎   | 50/80 [1:22:40<49:38, 99.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  64%|██████▍   | 51/80 [1:24:19<47:58, 99.25s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  65%|██████▌   | 52/80 [1:25:58<46:16, 99.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  66%|██████▋   | 53/80 [1:27:38<44:41, 99.32s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  68%|██████▊   | 54/80 [1:29:17<42:58, 99.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  69%|██████▉   | 55/80 [1:30:56<41:22, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  70%|███████   | 56/80 [1:32:36<39:47, 99.48s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  71%|███████▏  | 57/80 [1:34:15<38:04, 99.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  72%|███████▎  | 58/80 [1:35:55<36:26, 99.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  74%|███████▍  | 59/80 [1:37:34<34:47, 99.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  75%|███████▌  | 60/80 [1:39:13<33:06, 99.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  76%|███████▋  | 61/80 [1:40:53<31:28, 99.37s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  78%|███████▊  | 62/80 [1:42:32<29:45, 99.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  79%|███████▉  | 63/80 [1:44:11<28:07, 99.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  80%|████████  | 64/80 [1:45:50<26:28, 99.26s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  81%|████████▏ | 65/80 [1:47:29<24:48, 99.22s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  82%|████████▎ | 66/80 [1:49:09<23:10, 99.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  84%|████████▍ | 67/80 [1:50:48<21:30, 99.25s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  85%|████████▌ | 68/80 [1:52:27<19:50, 99.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  86%|████████▋ | 69/80 [1:54:06<18:09, 99.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  88%|████████▊ | 70/80 [1:55:45<16:31, 99.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 71/80 [1:57:24<14:51, 99.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 72/80 [1:59:04<13:13, 99.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████▏| 73/80 [2:00:43<11:33, 99.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▎| 74/80 [2:02:22<09:54, 99.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 75/80 [2:04:01<08:16, 99.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 76/80 [2:05:40<06:36, 99.22s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 77/80 [2:07:20<04:58, 99.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 78/80 [2:08:59<03:18, 99.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 79/80 [2:10:39<01:39, 99.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 80/80 [2:12:19<00:00, 99.24s/it]

# %%
#Read the data from the files to later apply a classifier


#First read the feature names
featureNames = np.genfromtxt('testData.txt', delimiter=',', max_rows=1, dtype=str)

#Then load the data
testData = np.loadtxt('testData.txt', delimiter=',', skiprows=1)
testLabels = np.loadtxt('testLabels.txt', delimiter=',', skiprows=1)

valData = np.loadtxt('valData.txt', delimiter=',', skiprows=1)
valLabels = np.loadtxt('valLabels.txt', delimiter=',', skiprows=1)

trainData = np.loadtxt('trainData.txt', delimiter=',', skiprows=1)
trainLabels = np.loadtxt('trainLabels.txt', delimiter=',', skiprows=1)

# %%
# Fit an XGBoost classifier and test it (with XGBClassifier), after performing hyperparameter grid search
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import numpy as np
import pandas as pd
import json

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 6, 9],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 3, 5],
    'reg_alpha': [0, 0.01, 0.1],
    'reg_lambda': [1, 1.5, 2]
}

# Combine train and validation data
combinedData = np.concatenate((trainData, valData), axis=0)
combinedLabels = np.concatenate((trainLabels, valLabels), axis=0)

# Create a validation fold index
test_fold = np.concatenate((
    np.full(trainData.shape[0], -1),  # -1 for training set
    np.zeros(valData.shape[0])        # 0 for validation set
))

# Create PredefinedSplit
ps = PredefinedSplit(test_fold)

# Initialize the model
model = XGBClassifier(
    objective='binary:logistic', 
    eval_metric='logloss',
    use_label_encoder=False,  
    tree_method='gpu_hist'  
)

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=ps,  # Use PredefinedSplit
    verbose=2,  # Set verbose to 2 for detailed progress information
    n_jobs=-1  # Use all available cores
)

# Fit GridSearchCV
grid_search.fit(combinedData, combinedLabels)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)
# Save the best parameters to a text file
with open('best_params.txt', 'w') as file:
    json.dump(best_params, file)
# Out:
# Fitting 1 folds for each of 19683 candidates, totalling 19683 fits
# c:\Users\equipo\.conda\envs\workenvAutoencoder2\lib\site-packages\xgboost\core.py:158: UserWarning: [18:14:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\equipo\.conda\envs\workenvAutoencoder2\lib\site-packages\xgboost\core.py:158: UserWarning: [18:14:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters found:  {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1.0}

# %%
#Load the best weights saved from a hyperparameter grid search and fit a classification model

import json
from xgboost import XGBClassifier

# Read the best parameters from the text file
with open('best_params.txt', 'r') as file:
    best_params = json.load(file)

# Initialize the model with the best parameters
model2 = XGBClassifier(
    objective='binary:logistic', 
    eval_metric='logloss',
    use_label_encoder=False,  # For compatibility
    tree_method='gpu_hist',  # Use GPU for training if available
    **best_params
)

# Fit the model using the training data
model2.fit(trainData, trainLabels, eval_set=[(valData, valLabels)], verbose=False)

# Make predictions on the test set
y_pred_prob = model2.predict_proba(testData)[:, 1]  # Probabilities
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert to binary predictions

# Confusion matrix
cm = confusion_matrix(testLabels, y_pred)
tn, fp, fn, tp = cm.ravel()  # Extract TN, FP, FN, TP

# Print results
print("\nClassification Report:\n", classification_report(testLabels, y_pred))
print("\nConfusion Matrix:")
print(cm)
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")

# Get feature importances
importances = model2.feature_importances_

# Create a DataFrame for feature importances
feature_importance_df = pd.DataFrame({
    'Feature': featureNames,
    'Importance': importances
})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the feature importances
print("\nFeature Importances:")
print(feature_importance_df)
# Out:
# c:\Users\equipo\.conda\envs\workenvAutoencoder2\lib\site-packages\xgboost\core.py:158: UserWarning: [14:51:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\equipo\.conda\envs\workenvAutoencoder2\lib\site-packages\xgboost\core.py:158: UserWarning: [14:51:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.88      0.90        40
#          1.0       0.88      0.93      0.90        40
#
#     accuracy                           0.90        80
#    macro avg       0.90      0.90      0.90        80
# weighted avg       0.90      0.90      0.90        80
#
#
# Confusion Matrix:
# [[35  5]
#  [ 3 37]]
# True Positives (TP): 37
# True Negatives (TN): 35
# False Positives (FP): 5
# False Negatives (FN): 3
#
# Feature Importances:
#                          Feature  Importance
# 10                lbp_uniformity    0.308641
# 11                      porosity    0.171244
# 0                       mean_val    0.101939
# 3                   kurtosis_val    0.066371
# 2                   skewness_val    0.062743
# 6                vert_coeff_mean    0.062640
# 1                   variance_val    0.060477
# 7               depth_coeff_mean    0.059422
# 5               horiz_coeff_mean    0.053868
# 9                   total_energy    0.052655
# 4              approx_coeff_mean    0.000000
# 8   dominant_frequency_magnitude    0.000000
